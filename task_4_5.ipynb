# %%
import numpy as np
import scipy
import scipy.linalg
import matplotlib.pyplot as plt

# %%
# Вычислите LU-разложение матрицы:

A = np.array([[1, 2, 3], [2, 16, 21], [4, 28, 73]])
P, L, U = scipy.linalg.lu(A)
print(P)
print(L)
print(U)
# Out:
# [[0. 1. 0.]
#  [0. 0. 1.]
#  [1. 0. 0.]]
# [[ 1.    0.    0.  ]
#  [ 0.25  1.    0.  ]
#  [ 0.5  -0.4   1.  ]]
# [[  4.    28.    73.  ]
#  [  0.    -5.   -15.25]
#  [  0.     0.   -21.6 ]]

# %%
#Найдите нормальное псевдорешение недоопределенной системы:
#x + 2y – z = 1  
#8x – 5y + 2z = 12
#Для этого определите функцию Q(x,y,z), равную норме решения, и найдите ее минимум. 

def Q(x, y, z):
    return (x**2 + y**2 + z**2)

x = np.linspace(-1, 3, 201)
plt.plot(x, Q(x, 10*x - 14, 21*x - 29))
plt.xlabel('x')
plt.ylabel('y')
plt.grid(True)
plt.show()

# %%
A = np.array([[1, 2, -1], [8, -5, 2]])
B = np.array([1, 12])
np.linalg.lstsq(A, B)
# Out:
# <ipython-input-12-d93be9187394>:3: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   np.linalg.lstsq(A, B)
# (array([ 1.38191882, -0.18081181,  0.0202952 ]),
#  array([], dtype=float64),
#  2,
#  array([9.65316119, 2.41173777]))

# %%
from pylab import *
from mpl_toolkits.mplot3d import Axes3D
fig = figure()
ax = Axes3D(fig)
X = np.arange(-10, 5, 0.5)
Y = np.arange(-10, 5, 0.5)
X, Y = np.meshgrid(X, Y)
Z = X + 2*Y + 1
X1 = np.arange(-10, 5, 0.5)
Y1 = np.arange(-10, 5, 0.5)
X1, Y1 = np.meshgrid(X1, Y1)
Z1 = 6 - 4*X1 + 2.5*Y1
ax.plot_wireframe(X,Y,Z, 1,  'yellow')
ax.plot_wireframe(X1,Y1,Z1)
ax.scatter(0, 0, 0, 'z', 50, 'red')
show()
